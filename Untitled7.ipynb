# %%
# !pip install selenium

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path=r'C:\webdrivers\chromedriver.exe')

# %%
driver.get(r"U:/stage1/yw@sf.beed540447-3bd2-4adf-857f-1f468d1b6e4a.html")

# %%
print(driver.title)

# %%
search = driver.page_source

# %%
phone = re.findall(r'',search)

# %%
e=driver.find_element_by_id("mainContentWithHeader").text
 
print(e)
 
driver.close()

# %%
import spacy
import pandas as pd
from spacy import displacy
#nlp = spacy.load('fr')
nlp = spacy.load("fr_core_news_md")

# %%
df =  pd.read_excel('final_210504_tous labels_complet.xlsx',engine='openpyxl')

# %%
for i in df.index:
    doc = nlp(df['Messages'][i]) 
    for ent in doc.ents:
        print(ent.text, ent.label_)
# Out:
# Bonjour MISC
# Ci-joint MISC
# sepa ORG
# CordialementBLACKSTONEBertrand MISC
# STRAZELTel MISC
# GUEGANSOCIETE DES TRANSPORTS ORG
# FONTAINGUY 35290 MISC
# ST MISC
# ONEN MISC
# CHAPELLE FRANCEBonjour MISC
# En mettant à jour nos badges MISC
# 26.08.2020.Vous MISC
# Léone GUEGANSociété PER
# Transports GUEGAN ORG
# Bonjour MISC
# EC 418 KS MISC
# DW-641-BJ MISC
# VIA ORG
# nouveau camionn PER
# svp  PER
# Les Planches LOC
# GENEUILLE MISC
# Bonjour MISC
# JEZEQUEL-------- Message PER
# WRDate : MISC
# Julien Jézéquel PER
# Julien PER
# Ci-joint MISC
# Mike ORG
# Pascale MISC
# No Message MISC
# Bonjour MISC
# Allemagne LOC
# Autriche LOC
# Autriche LOC
# Allemagne LOC
# TOLL MISC
# Autriche LOC
# Andreia Fernandes   Tel PER
# Fax PER
# Anosa Transportar PER
# Esta mensagem é confidencial LOC
# solicitamos PER
# assim como qualquer documento anexo PER
# DISCLAIMER MISC
# This message is confidential and intended exclusively for the MISC
# ...

# %%
doc = nlp("Demain je travaille en France chez Tableau")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# France LOC
# Tableau MISC
